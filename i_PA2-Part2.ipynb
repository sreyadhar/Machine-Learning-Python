# %% [markdown]
# # CSE474/574 - Programming Assignment 2

# %% [markdown]
# ## Part 2 - Image Classification with Multi-layer Perceptrons
#
# Additional library requirement: `Pillow`. See [here](https://anaconda.org/anaconda/pillow) for installation instructions.

# %%
# !pip install Pillow

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import sys
# sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/CSE 574/PA2')

# %%
import numpy as np
import pickle
from PIL import Image
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import time
from math import sqrt
import nnfunctions_1
import importlib
# %matplotlib inline

# %%
# run this cell if you modified the nnFunctions.py file and you wish to reload the module
importlib.reload(nnfunctions_1)
# Out:
# <module 'nnfunctions_1' from '/content/nnfunctions_1.py'>

# %%
classes = ['apple', 'airplane', 'basketball', 'axe', 'banana', 'horse', 'arm', 'alarm clock', 'ant', 'bed']

# %%
# load data
train_data,train_label,test_data,test_label = pickle.load(open('AI_quick_draw_sm.pickle','rb'))

# %%
# visualize some images
fig = plt.figure(figsize=[6,6])
for i in range(36):
    ax = plt.subplot(6,6,i+1)    
    ind = np.random.randint(0,train_data.shape[0])
    plt.imshow(train_data[ind,:].reshape((28,28)),cmap='Greys')
    plt.xticks([])
    plt.yticks([])
    t = plt.title(classes[int(train_label[ind])])
plt.tight_layout()

# %%
#  Train Neural Network
# set the number of nodes in input unit (not including bias unit)
n_input = train_data.shape[1]
print(n_input)
# set the number of nodes in hidden unit or M (not including bias unit)
n_hidden = 50 # you can modify this parameter

# set the number of nodes in output unit
n_class = len(np.unique(train_label)) # this parameter is fixed
print(n_class)
# initialize the weights into some random matrices
initial_W1 = nnfunctions_1.initializeWeights(n_input, n_hidden)
initial_W2 = nnfunctions_1.initializeWeights(n_hidden, n_class)

# unroll 2 weight matrices into single column vector
initialWeights = np.concatenate((initial_W1.flatten(), initial_W2.flatten()), 0)

# set the regularization hyper-parameter
lambdaval = 0 # you can modify this parameter

args = (n_input, n_hidden, n_class, train_data, train_label, lambdaval)

# Train Neural Network using fmin_cg or minimize from scipy,optimize module. 
# Check documentation for a working example
opts = {'maxiter': 50}  # Preferred value.
st = time.time()
nn_params = minimize(nnfunctions_1.nnObjFunction, initialWeights, jac=True, args=args, method='CG', options=opts)
en = time.time()
# Reshape nnParams from 1D vector into W1 and W2 matrices
W1 = nn_params.x[0:n_hidden * (n_input + 1)].reshape((n_hidden, (n_input + 1)))
W2 = nn_params.x[(n_hidden * (n_input + 1)):].reshape((n_class, (n_hidden + 1)))
print("Training completed in {:.2f} seconds.".format(en-st))

# Test the computed parameters

# find the accuracy on Training Dataset
predicted_label = nnfunctions_1.nnPredict(W1, W2, train_data)
print('Training set Accuracy: {:.2f}%'.format(100 * np.mean((predicted_label == train_label.astype(float)))))

# find the accuracy on Testing Dataset
predicted_label = nnfunctions_1.nnPredict(W1, W2, test_data)
print('Test set Accuracy    : {:.2f}%'.format(100 * np.mean((predicted_label == test_label.astype(float)))))
# Out:
# 784
# 10
# (25000, 25000)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-010c26fdb473> in <module>()
#      25 opts = {'maxiter': 50}  # Preferred value.
#      26 st = time.time()
# ---> 27 nn_params = minimize(nnfunctions_1.nnObjFunction, initialWeights, jac=True, args=args, method='CG', options=opts)
#      28 en = time.time()
#      29 # Reshape nnParams from 1D vector into W1 and W2 matrices
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     600         return _minimize_powell(fun, x0, args, callback, **options)
#     601     elif meth == 'cg':
# --> 602         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     603     elif meth == 'bfgs':
#     604         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1309     else:
#    1310         grad_calls, myfprime = wrap_function(fprime, args)
# -> 1311     gfk = myfprime(x0)
#    1312     k = 0
#    1313     xk = x0
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in derivative(self, x, *args)
#      71             return self.jac
#      72         else:
# ---> 73             self(x, *args)
#      74             return self.jac
#      75
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# /content/nnfunctions_1.py in nnObjFunction(params, *args)
#      85     # Forward Feed Propagation
#      86     bias_hidden = np.ones(train_data.shape[1], dtype=np.int8) # Added a column for bias with value 1
# ---> 87     train_data = np.column_stack([train_data, bias_hidden])
#      88     sum_hidden = np.dot(train_data, W1.T)  # sum_z at hidden layer 50000*50
#      89     output_hidden = sigmoid(sum_hidden)# output at hidden layer 50000*50
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 25000 and the array at index 1 has size 784

# %%
# visualize prediction on a random image
rnd_ind = np.random.randint(test_label.shape[0])
predicted_label = nnFunctions.nnPredict(W1,W2,test_data[rnd_ind:rnd_ind+1,:])
if predicted_label[0] == test_label[rnd_ind]:
    params = {"text.color" : "green"}
else:
    params = {"text.color" : "red"}
plt.rcParams.update(params)

plt.imshow(test_data[rnd_ind,:].reshape((28,28)),cmap='Greys')
t = plt.title('True - {}, Predicted - {}'.format(classes[int(test_label[rnd_ind])],classes[int(predicted_label[0])]))
